# %%
pip install tweepy

# %% [markdown]
#  **Scrapping with the Twitter API and importing all libraries**

# %% [markdown]
# The first task is to access into the Twitter API application to have the functionalities offer by Twitter. In this way, one can acceed to the account of twitter developer.

# %%
import csv
import tweepy
import ssl
import pandas as pd
import time
ssl._create_default_https_context = ssl._create_unverified_context
# Oauth keys
consumer_key = "q1agMwCJIKCtKgtr2kiyoAMYW"
consumer_secret = "g66x5NIsKCe0pmtgfd4viHjbTCXCM7FUO8aiGZuTgkheHkZHKjK"
access_token = "1572913917864677376-AetT8sh16f6frNFfd0wh7jMCi2WdK5"
access_token_secret = "lyy2bv7ze10QNGSmmVAx8Wox5t8idSf1wx6ODLMRMR721"
# Authentication with Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# To create dataframes that store the twitter comments of all the accounts inside the list name_accounts. **RUN THIS ALWAYS!**

# %%
name_accounts = ['iaeaorg','NRCgov','WECNuclear','CTBTO','WorldNuclear','W_Nuclear_News','ANS_org','GovNuclear','OECD_NEA'] #accounts
#IAEA, Nuclear US Regulatory Comission, Westignhouse Electrical Company, CTBTO, World Nuclear Association, World Nuclear News, 
#American Nuclear Society, Office of Nuclear Energy of the US, Nuclear Energy Agency
accounts_dfs = {}
for name in name_accounts:
  accounts_dfs[name] = pd.DataFrame()

# %% [markdown]
# To scrape all the tweets coming from a twitter account with date, ID, text, user name, hastags and symbols using the function twitterscrap

# %%
def twitterscrap(name, count):
  """
  This function extracts the tweets of the username 
  input:
  - name: name of the account 
  - count: number of tweets desired 
  ouput:
  - dataframe: this dataframe contains the date, id, text, username, retweets counts, location, language, favorites counts and hashtags used by the username
  """
  try:     
    # Creation of query method using appropriate parameters
    tweets = tweepy.Cursor(api.user_timeline,id=name,tweet_mode='extended').items(count)#take care of extracting the fuel twitter: 280 characters
    # Pulling information from tweets iterable object and adding relevant tweet information in our data frame
    for tweet in tweets:
      accounts_dfs[name] = accounts_dfs[name].append({'Created at' : tweet._json['created_at'],'ID': tweet._json['id'],
                                                    'Text': tweet._json['full_text'],'User Name':tweet.user._json['name'], 'Retweet counts' : tweet._json['retweet_count'],
                                                    'Location' : tweet.user._json['location'],'Language' : tweet._json['lang'],
                                                    'Favorites counts': tweet._json['favorite_count'],'Hashtags':tweet._json['entities']['hashtags']},ignore_index=True)
  except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)
  return accounts_dfs[name]

# %%
twitterscrap('OECD_NEA',5000)#'iaeaorg','NRCgov','WECNuclear','CTBTO','WorldNuclear','W_Nuclear_News','ANS_org','GovNuclear','OECD_NEA' these are the names of the profiles used

# %%
accounts_dfs['iaeaorg'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/iaeatweets.csv')
accounts_dfs['NRCgov'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/nrctweets.csv')
accounts_dfs['WECNuclear'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/westinghousetweets.csv')
accounts_dfs['CTBTO'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/ctbtoweets.csv')
accounts_dfs['WorldNuclear'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/worldnucleartweets.csv')
accounts_dfs['W_Nuclear_News'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/worldnuclearnewstweets.csv')
accounts_dfs['ANS_org'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/ANStweets.csv')
accounts_dfs['GovNuclear'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/NEofficetweets.csv')
accounts_dfs['OECD_NEA'].to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/NEAtweets.csv')

# %% [markdown]
# At this point, we have reached the dataframes that store the data of the 9 dataframes. Therefore, as we have created dataframes we can export it as .csv files and from now, we **simply read them and work with them.**

# %%
accounts_dfs['iaeaorg']= pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/iaeatweets.csv')
accounts_dfs['NRCgov']= pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/nrctweets.csv')
accounts_dfs['WECNuclear']=pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/westinghousetweets.csv')
accounts_dfs['CTBTO']=pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/ctbtoweets.csv')
accounts_dfs['WorldNuclear']=pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/worldnucleartweets.csv')
accounts_dfs['W_Nuclear_News']=pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/worldnuclearnewstweets.csv')
accounts_dfs['ANS_org']=pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/ANStweets.csv')
accounts_dfs['GovNuclear']=pd.read_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccounts/NEofficetweets.csv')

# %%
tweets_iaeaorg = accounts_dfs['iaeaorg']
tweets_nrcgov = accounts_dfs['NRCgov']
tweets_wecnuclear = accounts_dfs['WECNuclear']
tweets_ctbto = accounts_dfs['CTBTO']
tweets_worldnuclear = accounts_dfs['WorldNuclear']
tweets_worldnuclearnews = accounts_dfs['W_Nuclear_News']
tweets_americannuclearsociety = accounts_dfs['ANS_org']
tweets_govenergynuclear = accounts_dfs['GovNuclear']
tweets_nea = accounts_dfs['OECD_NEA']
#The previous datasets contain all the data that we will analyze.

# %%
tweets_iaeaorg.head(1)
# Out:
#    Unnamed: 0                      Created at            ID  \
# 0           0  Thu Dec 22 05:30:00 +0000 2022  1.605798e+18
#
#                                                 Text  \
# 0  💡 Curious to discover how irradiation ☢️ helps...
#
#                                       User Name  Retweet counts  \
# 0  IAEA - International Atomic Energy Agency ⚛️             6.0
#
#           Location Language  Favorites counts  \
# 0  Vienna, Austria       en              16.0
#
#                                             Hashtags
# 0  [{'text': 'SDG2', 'indices': [116, 121]}, {'te...

# %%
def cleaning_officialtweets(dataframe):
  """
  This function cleans the dataframe and organizes for further analysis
  input: dataframes to clean
  output:cleaned dataframes
  """
  dataframe['Date'] =  pd.to_datetime(dataframe['Created at'], infer_datetime_format=True)
  dataframe['Day'] = dataframe['Date'].dt.day
  dataframe['Month'] = dataframe['Date'].dt.month
  dataframe['Year'] = dataframe['Date'].dt.year
  dataframe['ID'] = dataframe['ID'].astype(int)
  dataframe = dataframe.drop_duplicates()
  dataframe = dataframe.drop(columns=['Unnamed: 0','Created at'])
  dataframe = dataframe[['ID', 'Date','Day', 'Month', 'Year', 'User Name','Location','Text','Language','Retweet counts','Favorites counts','Hashtags']]
  return dataframe

# %% [markdown]
# To clean the data from the official accounts and organise it in the correct format with date, text, hashtags, and id of the tweet for a future comments inspection.

# %%
tweets_iaeaorg = cleaning_officialtweets(tweets_iaeaorg).drop_duplicates().reset_index().drop(columns = 'index')
tweets_nrcgov = cleaning_officialtweets(tweets_nrcgov)
tweets_wecnuclear = cleaning_officialtweets(tweets_wecnuclear)
tweets_ctbto = cleaning_officialtweets(tweets_ctbto)
tweets_worldnuclear = cleaning_officialtweets(tweets_worldnuclear)
tweets_worldnuclearnews = cleaning_officialtweets(tweets_worldnuclearnews)
tweets_americannuclearsociety = cleaning_officialtweets(tweets_americannuclearsociety).drop_duplicates().reset_index().drop(columns = 'index')
tweets_govenergynuclear = cleaning_officialtweets(tweets_govenergynuclear)
#tweets_nea = cleaning_officialtweets(tweets_nea)

# %%
tweets_iaeaorg.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/iaeatweetsarr.csv')
tweets_nrcgov.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/nrctweetsarr.csv')
tweets_wecnuclear.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/westinghousetweetsarr.csv')
tweets_ctbto.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/ctbtotweetsarr.csv')
tweets_worldnuclear.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/worldnucleartweetsarr.csv')
tweets_worldnuclearnews.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/worldnuclearnewstweetsarr.csv')
tweets_americannuclearsociety.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/ANStweetsarr.csv')
tweets_govenergynuclear.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/NEofficetweetsarr.csv')
tweets_nea.to_csv('/content/drive/MyDrive/1stProject/TweetsOfficialAccountsArranged/NEAtweetsarr.csv')

# %% [markdown]
# At this point, the datasets contain an ID, day, month and year, the username, location, the text, language, retweetcounts, favorites counts, and the hashtags and are stored in the folder *TweetsOfficialAccountsArranged*

# %% [markdown]
# **Data visualization on the twitter official accounts**

# %%
tweets_iaeaorg.head(1)
# Out:
#                     ID                      Date  Day  Month  Year  \
# 0  1605797782392012800 2022-12-22 05:30:00+00:00   22     12  2022
#
#                                       User Name         Location  \
# 0  IAEA - International Atomic Energy Agency ⚛️  Vienna, Austria
#
#                                                 Text Language  Retweet counts  \
# 0  💡 Curious to discover how irradiation ☢️ helps...       en             6.0
#
#    Favorites counts                                           Hashtags
# 0              16.0  [{'text': 'SDG2', 'indices': [116, 121]}, {'te...

# %% [markdown]
# --------------------------------------------------------------------------------
# **SCRAPPING THE REPLIES OF THE NON OFFICIAL USERS**

# %% [markdown]
# Scrapping the **comments and aggrupate** them according to the IDs.
# It means, for each ID, its required to extract the correspondent comment for all the 3250 tweets and for all the profiles or usernames.

# %%
comments_dfs = {}
for name in name_accounts:
  comments_dfs[name] = pd.DataFrame()

# %%
import numpy as np
for name in name_accounts:
  comments_dfs[name]['ID'] = accounts_dfs[name]['ID']
  comments_dfs[name]['comments'] = np.nan
  comments_dfs[name]['ID'] = comments_dfs[name]['ID'].astype(int)
#All the dataframes that content IDs of comments and future comments are already created.

# %%
comments_dfs['iaeaorg'].head(2)

# %% [markdown]
# Now, lets work with the comments that were done in each publication for the IAEA case, once it is done I will move to the other cases.

# %%
comments_iaea = dict(zip(comments_dfs['iaeaorg'].ID,comments_dfs['iaeaorg'].comments)) #dictionary with ids and comments 
IDs_iaeaorg = list(comments_iaea.keys()) #this list contains 3250 tweets

# %%
api = tweepy.API(auth,wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
name = 'iaeaorg' #username to extract the comments
replies_iaea=[]

# %%
tweet_id = str(IDs_iaeaorg[15]) #id of the twitter
for tweet in tweepy.Cursor(api.search,q='to:'+name, result_type='recent', tweet_mode='extended', timeout=999999).items(100):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies_iaea.append(tweet._json)

# %%
sample_tweet = tweets_iaeaorg['Text'][15]
sample_tweet
# Out:
# 'Nuclear power plants are built to last, but as the #climatecrisis worsens, their adaptable workforces and robust designs will be essential to staying resilient and contributing to a low-carbon energy future. 👉 https://t.co/pCkScgqI0O #Atoms4Climate https://t.co/xBX7Em4vGJ'

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
replies_iaea[-1]['full_text']
# Out:
# '@iaeaorg This is the most obscene form of propaganda &amp; outright lying I have ever seen from the @UN. As nuclear power plants age, they become more dangerous, especially with on-site storage of spent nuclear fuel. Why does the UN have a nuclear pimping agency? Contradicts the #TPNW'
